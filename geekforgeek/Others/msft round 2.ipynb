# %%
1. SQL Question: Imagine Bing data.

PAGEVIEWS 
•  PageviewID - unique ID of the specific page view 
•  Query - text that the user typed in to perform the query 
•  Timestamp 

CLICKS 
•  ClickID - unique ID of the specific click 
•  PageviewID - the ID of the page in which the click happened 
•  Timestamp 

Write a SQL query that gives click through rate by Bing query.

select query, count(b.clickID)/ count(distinct(a.PageviewID))
from pageviews a left join with clicks b
on a.pageviewID = b.pageviewID
group by query


2. Given an input array of n integers, write code that gives the maximum sum of a sliding window of length k. 
For example, if the input array is 
 
A= [1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1]  and k=3, output = 19  
A = [-1,-2, -5, -7]

def find_max_sum(arr , k)
max_till_now = -inf
temp_sum = 0

#if len(A) < k this wont work

for i in range(k, len(arr)+1):
temp_sum = 0
for j in range(i-k, i)
temp_sum += arr[j]

if temp_sum > max_till_now:
max_till_now = temp_sum
return max_till_now


def find_max_sum(arr , k)
max_till_now = -inf
temp_sum = 0

#if len(A) < k this wont work

for i in range(k, len(arr)+1):
if i == 0:
for j in range(i-k, i):
temp_sum += arr[j]
else:
last_sum = temp_sum - arr[i-k]
temp_sum = last_sum + arr[i]
  
if temp_sum > max_till_now:
max_till_now = temp_sum

return max_till_now

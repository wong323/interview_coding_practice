# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class solution (object):
    
    def 
    
    
    def find_cheapest (self, edges, scr, dest, k):
        cost = 1
        return cost
    
edges = [[0,1,100], [1,2,100], [0,2,500]]
scr = 0
dest = 2
k = 1

x = solution()
y = x.find_cheapest(edges, scr, dest, k)
print(y)
# Out:
# 1
